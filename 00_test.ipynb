# %% [markdown]
# #To develop a quality check mechanism on the basis of purity, pH, moisture content and grade them based on the assignned parameters.
# #Here more than ogive method is opted such that based on lower boundary conditions batches are graded.
#
# Batch_number = int(input("Enter the Batch number: "))
# purity = float(input("Enter the purity of the product (as percent): "))
# pH = float(input("Enter the pH of the product: "))
# moisture = float(input("Enter the moisture content of the product (as percent): "))
#
#
# if  0<= purity <= 100:
#     if 0<= moisture <= 100:
#         if 0<= pH <= 14:
#             if  purity >= 98.00 and 6.5 <= pH <= 7.5 and moisture <= 1.0:
#                 classification = "Grade A"
#                 status = "Approved for release"
#             elif  purity >= 95.00 and 6.0 <= pH <= 8.0 and moisture <= 2.0:
#                 classification = "Grade B"
#                 status = "Approved for release"
#             elif  purity >= 90.00 and 5.0 <= pH <= 9.0 and moisture <= 4.0:
#                 classification = "Grade C"
#                 status = "Approved for release"
#             else:
#                 classification = "Rejected"
#                 status = "Rejected for release"
#         else:
#             classification = "Invalid input: Recheck pH should be in range of 0 to 14"
#             status = "Quarantined"
#     else:
#         classification = "Invalid input: Recheck moisture content should be in percent and lie between 0 to 100"
#         status = "Quarantined"
# else:
#     classification = "Invalid input: Recheck purity should be in percent and lie between 0 to 100"
#     status = "Quarantined"
#
# print("       Quality Check Report")
# print("----------------------------------")
# print(f"Batch number:           {Batch_number}")
# print("----------------------------------")
# print(f"Entered purity:         {purity}%")
# print(f"Entered pH:             {pH}")
# print(f"Entered moisture:       {moisture}%")
# print("----------------------------------")
# print(f"Product Grade: {classification}")
# print("----------------------------------")
# print(f"Product status:   {status} **")

# %%
# Activity 4
# Add conversion (%) to your numerical integration program.
import math
C = float(input("Enter the initial concentration in moles per liter: "))
k = float(input("Enter the rate constant in inverse minutes: "))
dt = float(input("Enter the time step in minutes: "))
A = float(input("Enter the desired conversion percentage: "))
i = float(input("Enter the maximum time in minutes: "))
t = 0.0
conversion = 0.0
# Store the initial concentration for conversion calculation
C0 = C
if C0 > 0 and k > 0 and dt > 0:
    while conversion < A and t < i: 
        #print(f"{i} minutes")
        dCdt = -k * C
        C = C + dCdt * dt
        conversion = ((C0 - C) / C0) * 100
        t = t + dt
    absolute_error = abs(C - (C0 * math.exp(-k * t)))
    print(f"Final time: {t:.2f} minutes")
    print(f"Final concentration: {C:.4f} mol/L")
    print(f"Final conversion: {conversion:.2f}%")
    print(f"Absolute error: {absolute_error:.4f}")
else: 
    print("Parameters entered must be greater than zero.")
# Out:
# Final time: 393222.57 minutes
# Final concentration: 1.4000 mol/L
# Final conversion: 86.00%
# Absolute error: 0.0000

# %%
# Activity 5
# Use a while loop for the target-conversion simulation.
t = 0 
while t <= 10:
    print(f"{t} minutes")
    t = t +  1
print("Activity Done.")
# Out:
# 0 minutes
# 1 minutes
# 2 minutes
# 3 minutes
# 4 minutes
# 5 minutes
# 6 minutes
# 7 minutes
# 8 minutes
# 9 minutes
# 10 minutes
# Activity Done.

# %%
# Activity 4
# Add conversion (%) to your numerical integration program.
import math
C = float(input("Enter the initial concentration in moles per liter: "))
k = float(input("Enter the rate constant in inverse minutes: "))
dt = float(input("Enter the time step in minutes: "))
A = float(input("Enter the desired conversion percentage: "))
i = float(input("Enter the maximum time in minutes: "))
t = 0.0
conversion = 0.0
# Store the initial concentration for conversion calculation
C0 = C
if C0 > 0 and k > 0 and dt > 0:
    while conversion < A and t < i: 
        #print(f"{i} minutes")
        dCdt = -k * C
        C = C + dCdt * dt
        conversion = ((C0 - C) / C0) * 100
        t = t + dt
    absolute_error = abs(C - (C0 * math.exp(-k * t)))
    P = ("Report was sucessfully generated based on the provided parameters.")
else: 
    P = ("Parameter enetered must be greater than zero.")
    t = ("*")
    conversion = ("*")
    absolute_error = ("*")
print("* Numerical Integration & Chemical Kinetics Simulation Report *")
print("-------------------------------------------------------------")
print("Input:-")
print(f"Initial concentration:   {C0:.4f} mol/L")
print(f"Rate constant:           {k:.4f} 1/min")
print(f"Time step:               {dt:.4f} minutes")
print(f"Desired conversion:      {A:.2f}%")
print("-------------------------------------------------------------")
print("Output:-")
print(f"Final time:              {t:.2f} minutes")
print(f"Final concentration:     {C:.4f} mol/L")
print(f"Final conversion:        {conversion:.2f}%")
print(f"Absolute error:          {absolute_error:.4f}")
print("-------------------------------------------------------------")
print(f"{P}")
# Out:
# * Numerical Integration & Chemical Kinetics Simulation Report *
# -------------------------------------------------------------
# Input:-
# Initial concentration:   1.0000 mol/L
# Rate constant:           0.5000 1/min
# Time step:               1.0000 minutes
# Desired conversion:      80.00%
# -------------------------------------------------------------
# Output:-
# Final time:              3.00 minutes
# Final concentration:     0.1250 mol/L
# Final conversion:        87.50%
# Absolute error:          0.0981
# -------------------------------------------------------------
# Report was sucessfully generated based on the provided parameters.

# %%
# FINAL PROGRAM
# Batch Reaction Numerical Integrator
# Write your clean final solution here.
import math
D = input("Is it conversion bound? (Yes/No): ")
I = input("Is it time bound? (Yes/No): ")
C = float(input("Enter the initial concentration in moles per liter: "))
k = float(input("Enter the rate constant in inverse minutes: "))
dt = float(input("Enter the time step in minutes: "))

if D.lower() == "yes" and I.lower() == "yes":
        A = float(input("Enter the desired conversion percentage: "))
        i = float(input("Enter the maximum time in minutes: "))
        t = 0.0
        conversion = 0.0
        # Store the initial concentration for conversion calculation
        C0 = C
        if C0 > 0 and k > 0 and dt > 0 and 0 <= A <= 100 and i > 0:
            while conversion < A and t < i: 
                #print(f"{i} minutes")
                dCdt = -k * C
                C = C + dCdt * dt
                conversion = ((C0 - C) / C0) * 100
                t = t + dt
            absolute_error = abs(C - (C0 * math.exp(-k * t)))
            P = ("Report was sucessfully generated based on the provided parameters.")
        else: 
            P = ("Parameter enetered must be greater than zero.")
            t = ("*")
            conversion = ("*")
            absolute_error = ("*")
        print("* Numerical Integration & Chemical Kinetics Simulation Report *")
        print("---------------------------------------------------------------")
        print("Input:-")
        print(f"Initial concentration:   {C0:.4f} mol/L")
        print(f"Rate constant:           {k:.4f} 1/min")
        print(f"Time step:               {dt:.4f} minutes")
        print(f"Desired conversion:      {A:.2f}%")
        print("---------------------------------------------------------------")
        print("Output:-")
        print(f"Final time:              {t:.2f} minutes")
        print(f"Final concentration:     {C:.4f} mol/L")
        print(f"Final conversion:        {conversion:.2f}%")
        print(f"Absolute error:          {absolute_error:.4f}")
        print("---------------------------------------------------------------")
        print(f"{P}")
elif D.lower() == "yes" and I.lower() == "no":
        A = float(input("Enter the desired conversion percentage: "))
        t = 0.0
        conversion = 0.0
        # Store the initial concentration for conversion calculation
        C0 = C
        if C0 > 0 and k > 0 and dt > 0 and 0 <= A <= 100:
            while conversion == A: 
                #print(f"{i} minutes")
                dCdt = -k * C
                C = C + dCdt * dt
                conversion = ((C0 - C) / C0) * 100
                t = t + dt
            absolute_error = abs(C - (C0 * math.exp(-k * t)))
            P = ("Report was sucessfully generated based on the provided parameters.")
        else: 
            P = ("Parameter enetered must be greater than zero.")
            t = ("*")
            conversion = ("*")
            absolute_error = ("*")
        print("* Numerical Integration & Chemical Kinetics Simulation Report *")
        print("---------------------------------------------------------------")
        print("Input:-")
        print(f"Initial concentration:   {C0:.4f} mol/L")
        print(f"Rate constant:           {k:.4f} 1/min")
        print(f"Time step:               {dt:.4f} minutes")
        print(f"Desired conversion:      {A:.2f}%")
        print("---------------------------------------------------------------")
        print("Output:-")
        print(f"Final time:              {t:.2f} minutes")
        print(f"Final concentration:     {C:.4f} mol/L")
        print(f"Final conversion:        {conversion:.2f}%")
        print(f"Absolute error:          {absolute_error:.4f}")
        print("---------------------------------------------------------------")
        print(f"{P}")
elif D.lower() == "no" and I.lower() == "yes":
        A = 100
        i = float(input("Enter the maximum time in minutes: "))
        t = 0.0
        conversion = 0.0
        # Store the initial concentration for conversion calculation
        C0 = C
        if C0 > 0 and k > 0 and dt > 0 and i > 0:
            while conversion == A == 100 and t < i: 
                #print(f"{i} minutes")
                dCdt = -k * C
                C = C + dCdt * dt
                conversion = ((C0 - C) / C0) * 100
                t = t + dt
            absolute_error = abs(C - (C0 * math.exp(-k * t)))
            P = ("Report was sucessfully generated based on the provided parameters.")
        else: 
            P = ("Parameter enetered must be greater than zero.")
            t = ("*")
            conversion = ("*")
            absolute_error = ("*")
        print("* Numerical Integration & Chemical Kinetics Simulation Report *")
        print("---------------------------------------------------------------")
        print("Input:-")
        print(f"Initial concentration:   {C0:.4f} mol/L")
        print(f"Rate constant:           {k:.4f} 1/min")
        print(f"Time step:               {dt:.4f} minutes")
        print(f"Maximum time:            {i:.2f} minutes")
        print("---------------------------------------------------------------")
        print("Output:-")
        print(f"Final time:              {t:.2f} minutes")
        print(f"Final concentration:     {C:.4f} mol/L")
        print(f"Final conversion:        {conversion:.2f}%")
        print(f"Absolute error:          {absolute_error:.4f}")
        print("---------------------------------------------------------------")
        print(f"{P}")
elif D.lower() == "no" and I.lower() == "no":
        A = 100
        t = 0.0
        conversion = 0.0
        # Store the initial concentration for conversion calculation
        C0 = C
        if C0 > 0 and k > 0 and dt > 0:
            while conversion == A == 100:
                #print(f"{i} minutes")
                dCdt = -k * C
                C = C + dCdt * dt
                conversion = ((C0 - C) / C0) * 100
                t = t + dt
                absolute_error = abs(C - (C0 * math.exp(-k * t)))
                P = ("Report was sucessfully generated based on the provided parameters.")
        else: 
            P = ("Parameter enetered must be greater than zero.")
            t = ("*")
            conversion = ("*")
            absolute_error = ("*")
        print("* Numerical Integration & Chemical Kinetics Simulation Report *")
        print("---------------------------------------------------------------")
        print("Input:-")
        print(f"Initial concentration:   {C0:.4f} mol/L")
        print(f"Rate constant:           {k:.4f} 1/min")
        print(f"Time step:               {dt:.4f} minutes")
        print("---------------------------------------------------------------")
        print("Output:-")
        print(f"Final time:              {t:.2f} minutes")
        print(f"Final concentration:     {C:.4f} mol/L")
        print(f"Final conversion:        {conversion:.2f}%")
        print(f"Absolute error:          {absolute_error:.4f}")
        print("---------------------------------------------------------------")
        print(f"{P}")
else:
        print("Invalid input. Please enter 'Yes' or 'No' for both conversion and time bound questions.")

# %%
import math
x = 1
math.exp(x)
print(math.exp(1))
# C = C0 * math.exp(-k * t)
# Out:
# 2.718281828459045

# %% [markdown]
# # Quality Check of product based on Purity -> pH -> Moisture content and grade them based on these parameters.
# purity = float(input("Enter the purity percent: "))
# pH = float(input("Enter the pH: "))
# Moisture = float(input("Enter the Moisture content percent: "))
#
# if purity >= 98:
#     if 6.5 < pH < 7.5 and Moisture  <=1:
#         print("Grade A")
#     elif 6.5 = pH and Moisture <=1:
#         print("Boundary Condition")
#     elif 7.5 = pH and Moisture <=1:
#         print("Boundary Condition")
# elif 95.00 <= purity <= 97.99:
#     if 6.0 < pH < 8.0 and Moisture  <=2:
#         print("Grade B")
#     elif 6.0 = pH and Moisture <=2:
#         print("Boundary Condition")
#     elif 8.0 = pH and Moisture <=2:
#         print("Boundary Condition")
# elif 90.00<= purity <= 94.99:
#     if 5.0 < pH < 9.0 and Moisture  <=4:
#         print("Grade C")
#     elif 5.0 = pH and Moisture <=4:
#         print("Boundary Condition")
#     elif 9.0 = pH and Moisture <=4:
#         print("Boundary Condition")
# elif purity <= 90.00:
#     elif 5.00 =< pH and Moisture >4:
#         print("Rejected")
#     elif 7.5 =>pH and Moisture >4:
#         print("Rejected")

# %% [markdown]
#
# # Get marks of a student and print the grade based on the marks
# marks = float(input("Enter the marks: "))
#
# if marks >= 95:
#     grade = "A"
# elif marks >= 85:
#     grade = "B"
# elif marks >= 75:
#     grade = "C"
# elif marks >= 65:
#     grade = "D"
# elif marks >= 55:
#     grade = "E"
# else:
#     grade = "F"
#
# print(f"Marks: {marks}")
# print(f"Grade: {grade}")

# %% [markdown]
# # Quality Check of product based on Purity -> pH -> Moisture content and grade them based on these parameters.
# purity = float(input("Enter the purity percent: "))
# pH = float(input("Enter the pH: "))
# Moisture = float(input("Enter the Moisture content percent: "))
#
# if purity >= 98:
#     if 6.5 < pH < 7.5 and Moisture <= 1:
#         print("Grade A")
#     elif pH == 6.5 and Moisture <= 1:
#         print("Boundary Condition")
#     elif pH == 7.5 and Moisture <= 1:
#         print("Boundary Condition")
#     else:
#         print("Rejected")
#
# elif 95.00 <= purity <= 97.99:
#     if 6.0 < pH < 8.0 and Moisture <= 2:
#         print("Grade B")
#     elif pH == 6.0 and Moisture <= 2:
#         print("Boundary Condition")
#     elif pH == 8.0 and Moisture <= 2:
#         print("Boundary Condition")
#     else:
#         print("Rejected")
#
# elif 90.00 <= purity <= 94.99:
#     if 5.0 < pH < 9.0 and Moisture <= 4:
#         print("Grade C")
#     elif pH == 5.0 and Moisture <= 4:
#         print("Boundary Condition")
#     elif pH == 9.0 and Moisture <= 4:
#         print("Boundary Condition")
#     else:
#         print("Rejected")
#
# else:  # purity < 90.00
#     print("Rejected")

# %% [markdown]
# # ---- Get inputs ----
# product_name = input("Enter product name: ")
# batch_no = input("Enter batch number: ")
# inspector = input("Enter inspector name: ")
#
# purity = float(input("Enter the purity percent: "))
# pH = float(input("Enter the pH: "))
# Moisture = float(input("Enter the Moisture content percent: "))
#
# # ---- Determine grade & remarks ----
# grade = None
# remarks = ""
#
# if purity >= 98:
#     if 6.5 < pH < 7.5 and Moisture <= 1:
#         grade = "Grade A"
#         remarks = "Meets all premium specifications."
#     elif pH == 6.5 and Moisture <= 1:
#         grade = "Boundary Condition"
#         remarks = "pH sits exactly at lower limit (6.5) — recheck advised."
#     elif pH == 7.5 and Moisture <= 1:
#         grade = "Boundary Condition"
#         remarks = "pH sits exactly at upper limit (7.5) — recheck advised."
#     else:
#         grade = "Rejected"
#         remarks = "High purity but pH/Moisture out of Grade A range."
#
# elif 95.00 <= purity <= 97.99:
#     if 6.0 < pH < 8.0 and Moisture <= 2:
#         grade = "Grade B"
#         remarks = "Meets standard specifications."
#     elif pH == 6.0 and Moisture <= 2:
#         grade = "Boundary Condition"
#         remarks = "pH sits exactly at lower limit (6.0) — recheck advised."
#     elif pH == 8.0 and Moisture <= 2:
#         grade = "Boundary Condition"
#         remarks = "pH sits exactly at upper limit (8.0) — recheck advised."
#     else:
#         grade = "Rejected"
#         remarks = "Purity acceptable but pH/Moisture out of Grade B range."
#
# elif 90.00 <= purity <= 94.99:
#     if 5.0 < pH < 9.0 and Moisture <= 4:
#         grade = "Grade C"
#         remarks = "Meets minimum acceptable specifications."
#     elif pH == 5.0 and Moisture <= 4:
#         grade = "Boundary Condition"
#         remarks = "pH sits exactly at lower limit (5.0) — recheck advised."
#     elif pH == 9.0 and Moisture <= 4:
#         grade = "Boundary Condition"
#         remarks = "pH sits exactly at upper limit (9.0) — recheck advised."
#     else:
#         grade = "Rejected"
#         remarks = "Purity acceptable but pH/Moisture out of Grade C range."
#
# else:
#     grade = "Rejected"
#     remarks = "Purity below 90% — does not meet minimum threshold."
#
# status = "PASS" if "Grade" in grade else ("REVIEW" if grade == "Boundary Condition" else "FAIL")
#
# # ---- Print formatted report ----
# print("\n" + "=" * 50)
# print("      QUALITY CONTROL INSPECTION REPORT")
# print("=" * 50)
# print(f"Product Name     : {product_name}")
# print(f"Batch No.        : {batch_no}")
# print(f"Inspected By     : {inspector}")
# print("-" * 50)
# print("TEST PARAMETERS")
# print(f"  Purity (%)     : {purity}")
# print(f"  pH             : {pH}")
# print(f"  Moisture (%)   : {Moisture}")
# print("-" * 50)
# print(f"RESULT           : {grade}")
# print(f"STATUS           : {status}")
# print(f"REMARKS          : {remarks}")
# print("=" * 50 + "\n")

# %%
# Activity 3
# For Kc = 4, calculate the quadratic coefficients and solve for x.
# Identify the physically meaningful root.

import math
A = input("Is it conversion bound? (Yes/No): ")
B = input("Is it time bound? (Yes/No): ")
C = float(input("Enter the initial concentration in moles per liter: "))


discriminant = b**2 - 4*a*c
print("The discriminant is:", discriminant)
if discriminant < 0:
    print("No real roots exist.")
else:
    root1 = (-b + discriminant**0.5) / (2*a)
    root2 = (-b - discriminant**0.5) / (2*a)
    print("The roots are:", root1, "and", root2)
    # Identify the physically meaningful root
    if 0 <= root1 <= 1:
        print("The physically feasible root is:", root1)
    elif 0 <= root2 <= 1:
        print("The physically feasible root is:", root2)
    else:
        print("No physically feasible roots exist.")

# %%
Kc = 4
a = Kc
b = -(2*Kc + 1)
c = Kc

D = b**2 - 4*a*c

x1 = (-b + D**0.5) / (2*a)
x2 = (-b - D**0.5) / (2*a)

print('x1 =', x1)
print('x2 =', x2)
# Out:
# x1 = 1.6403882032022077
# x2 = 0.6096117967977924
